# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch 

# Load the wind torch
wind_ts = torch.load('../data/cases/LEMD_EGLL/tres_runs/batch0/WIND_34520CIBE31HW_1680502713.pt')
print(f'wind_ts shape: {wind_ts.shape}')
# Out:
# wind_ts shape: torch.Size([7717])

# %%
wind_ts.histogram()
# Out:
# torch.return_types.histogram(
# hist=tensor([  9.,  25.,  13.,  15.,  50.,  32.,  51.,  70.,  57.,  45.,  44.,  84.,
#          82.,  61.,  77.,  87.,  82., 133., 145., 149., 184., 226., 221., 162.,
#         161., 160., 133., 228., 217., 214., 181., 190., 213., 149., 133., 145.,
#         158., 147., 131., 124., 141., 148., 123., 171., 132., 121., 127., 119.,
#         123., 101., 115.,  88.,  72.,  84.,  61.,  63.,  69.,  52.,  44.,  67.,
#          59.,  51.,  67.,  47.,  55.,  33.,  34.,  50.,  22.,  43.,  22.,  25.,
#          26.,  18.,  20.,  22.,  14.,  35.,  24.,  16.,  42.,  12.,  12.,   7.,
#          13.,  20.,  10.,  14.,   9.,  10.,  13.,   7.,   9.,   5.,   3.,   9.,
#           7.,   8.,  13.,   2.]),
# bin_edges=tensor([-74.9719, -74.0596, -73.1472, -72.2348, -71.3225, -70.4101, -69.4977,
#         -68.5854, -67.6730, -66.7607, -65.8483, -64.9359, -64.0235, -63.1112,
#         -62.1988, -61.2864, -60.3741, -59.4617, -58.5493, -57.6370, -56.7246,
# ...

# %%
import torch 

# Load the wind torch
wind_ts = torch.load('../data/cases/LEMD_EGLL/samples/flight0_wind_avg.pt')
print(f'wind_ts shape: {wind_ts.shape}')
# Out:
# wind_ts shape: torch.Size([14563])

# %%
wind_ts.histogram()
# Out:
# torch.return_types.histogram(
# hist=tensor([   3.,   10.,   10.,   10.,   12.,   15.,   12.,   36.,   35.,   46.,
#           46.,   38.,   40.,   52.,   50.,   52.,   59.,   60.,   64.,   62.,
#           64.,   31.,   41.,   47.,   55.,   45.,   65.,   54.,   79.,   74.,
#           71.,   83.,  101.,  109.,  118.,  119.,  125.,  145.,  131.,  165.,
#          207.,  200.,  198.,  174.,  167.,  156.,  201.,  273.,  451.,  678.,
#          555.,  468.,  626., 1011.,  956.,  690.,  455.,  323.,  286.,  245.,
#          226.,  238.,  192.,  188.,  179.,  182.,  157.,  140.,  127.,  139.,
#          134.,  161.,  116.,  104.,  113.,   99.,   79.,  103.,  108.,  103.,
#           75.,   67.,   55.,   58.,   49.,   61.,   56.,   61.,   54.,   22.,
#           19.,   38.,   57.,   77.,   45.,   49.,   38.,   19.,   15.,    6.]),
# bin_edges=tensor([-91.7044, -90.1021, -88.4997, -86.8974, -85.2950, -83.6927, -82.0903,
# ...
