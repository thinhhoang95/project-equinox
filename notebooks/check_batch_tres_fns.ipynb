# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle 

with open('D:\\project-equinox\\data\\cases\\LEMD_EGLL\\tres_runs\\batch0\\FW_3444C4IBE31HW_1680590659.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
# Print all transitions from 185
# Print all transitions that start with node index 185
transitions_from_185 = [t for t in data if t[0] == 185]
print(f"Found {len(transitions_from_185)} transitions starting from node 185:")
for i, transition in enumerate(transitions_from_185):
    print(f"{i+1}: {transition}")
# Out:
# Found 67 transitions starting from node 185:
# 1: (185, 0, 0.0, 546, 12, 15076.0)
# 2: (185, 0, 0.0, 472, 9, 12088.0)
# 3: (185, 0, 0.0, 491, 8, 10944.0)
# 4: (185, 0, 0.0, 331, 12, 15282.0)
# 5: (185, 0, 0.0, 351, 18, 21074.0)
# 6: (185, 0, 0.0, 12, 21, 24130.0)
# 7: (185, 0, 0.0, 255, 20, 23614.0)
# 8: (185, 0, 0.0, 349, 25, 27884.0)
# 9: (185, 0, 0.0, 519, 28, 30097.0)
# 10: (185, 0, 0.0, 258, 16, 19209.0)
# 11: (185, 0, 0.0, 513, 17, 20092.0)
# 12: (185, 0, 0.0, 339, 20, 23344.0)
# 13: (185, 0, 0.0, 16, 17, 20008.0)
# 14: (185, 0, 0.0, 268, 24, 27226.0)
# 15: (185, 0, 0.0, 447, 3, 4046.0)
# 16: (185, 0, 0.0, 387, 21, 24000.0)
# 17: (185, 0, 0.0, 5, 28, 30006.0)
# 18: (185, 0, 0.0, 402, 18, 21225.0)
# 19: (185, 0, 0.0, 469, 36, 35000.0)
# 20: (185, 0, 0.0, 358, 28, 29808.0)
# 21: (185, 0, 0.0, 315, 26, 28515.0)
# 22: (185, 0, 0.0, 556, 23, 26448.0)
# 23: (185, 0, 0.0, 102, 26, 28552.0)
# 24: (185, 0, 0.0, 429, 31, 31518.0)
# 25: (185, 0, 0.0, 81, 24, 26866.0)
# ...

# %%
import pickle 

with open('D:\\project-equinox\\data\\cases\\LEMD_EGLL\\tres_runs\\batch0\\BW_3444C4IBE31HW_1680590659.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
# Print all transitions from 185
# Print all transitions that start with node index 185
transitions_from_185 = [t for t in data if t[0] == 185]
print(f"Found {len(transitions_from_185)} transitions starting from node 185:")
for i, transition in enumerate(transitions_from_185):
    print(f"{i+1}: {transition}")
# Out:
# Found 246 transitions starting from node 185:
# 1: (185, 18, 0, 35000, 1, 540, 20, 0, 35000, 1)
# 2: (185, 18, 36, 0, 0, 540, 20, 0, 35000, 1)
# 3: (185, 19, 0, 35000, 1, 540, 21, 0, 35000, 1)
# 4: (185, 18, 36, 0, 0, 471, 20, 0, 35000, 1)
# 5: (185, 18, 0, 35000, 1, 471, 22, 0, 35000, 1)
# 6: (185, 19, 0, 35000, 1, 471, 23, 0, 35000, 1)
# 7: (185, 18, 36, 0, 0, 267, 20, 0, 35000, 1)
# 8: (185, 19, 0, 35000, 1, 267, 21, 0, 35000, 1)
# 9: (185, 18, 0, 35000, 1, 487, 20, 0, 35000, 1)
# 10: (185, 18, 36, 0, 0, 487, 20, 0, 35000, 1)
# 11: (185, 19, 0, 35000, 1, 487, 21, 0, 35000, 1)
# 12: (185, 18, 36, 0, 0, 43, 20, 0, 35000, 1)
# 13: (185, 19, 0, 35000, 1, 43, 22, 0, 35000, 1)
# 14: (185, 19, 0, 35000, 1, 43, 23, 0, 35000, 1)
# 15: (185, 18, 0, 35000, 1, 450, 21, 0, 35000, 1)
# 16: (185, 19, 0, 35000, 1, 450, 22, 0, 35000, 1)
# 17: (185, 18, 36, 0, 0, 550, 20, 0, 35000, 1)
# 18: (185, 18, 0, 35000, 1, 550, 21, 0, 35000, 1)
# 19: (185, 18, 0, 35000, 1, 550, 22, 0, 35000, 1)
# ...

# %% [markdown]
# # Verify thinned transitions

# %%
import pickle 

with open('D:\\project-equinox\\data\\cases\\LEMD_EGLL\\tres_runs\\batch0\\thinned_transitions.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
# Print all transitions from 185
# Print all transitions that start with node index 185
transitions_from_185 = [t for t in data if t[0] == 185]
print(f"Found {len(transitions_from_185)} transitions starting from node 185:")
for i, transition in enumerate(transitions_from_185):
    print(f"{i+1}: {transition}")
# Out:
# Found 1546 transitions starting from node 185:
# 1: (185, 19, 36, 0, 0, 540, 21, 0, 35000, 1)
# 2: (185, 19, 36, 0, 0, 502, 21, 0, 35000, 1)
# 3: (185, 19, 36, 0, 0, 291, 20, 0, 35000, 1)
# 4: (185, 19, 36, 0, 0, 292, 21, 0, 35000, 1)
# 5: (185, 19, 36, 0, 0, 118, 21, 0, 35000, 1)
# 6: (185, 19, 36, 0, 0, 314, 21, 0, 35000, 1)
# 7: (185, 19, 36, 0, 0, 469, 20, 0, 35000, 1)
# 8: (185, 19, 36, 0, 0, 274, 21, 0, 35000, 1)
# 9: (185, 20, 36, 0, 0, 274, 21, 1, 34265, 0)
# 10: (185, 19, 36, 0, 0, 300, 21, 0, 35000, 1)
# 11: (185, 19, 36, 0, 0, 488, 20, 0, 35000, 1)
# 12: (185, 20, 36, 0, 0, 488, 21, 0, 34694, 0)
# 13: (185, 19, 36, 0, 0, 488, 21, 0, 35000, 1)
# 14: (185, 19, 36, 0, 0, 158, 20, 0, 35000, 1)
# 15: (185, 19, 36, 0, 0, 190, 21, 0, 35000, 1)
# 16: (185, 19, 36, 0, 0, 190, 21, 1, 34350, 0)
# 17: (185, 19, 36, 0, 0, 358, 20, 0, 34611, 0)
# 18: (185, 19, 36, 0, 0, 358, 21, 0, 34611, 0)
# 19: (185, 19, 36, 0, 0, 368, 21, 0, 35000, 1)
# 20: (185, 19, 36, 0, 0, 231, 20, 0, 35000, 1)
# ...
